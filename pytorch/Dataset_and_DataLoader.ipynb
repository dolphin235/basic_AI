# %% [markdown]
# ## Dataset과 DataLoader
# - pytorch 에서는 데이터를 다루는 툴로 Dataset과 DataLoader를 제공
# - 이를 통해 미니 배치 학습, 데이터 셔플, 병렬 처리까지 수행이 가능
# - 사용법: Dataset을 정의 -> DataLoader에 전달

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from torch.utils.data import TensorDataset # 텐서데이터셋
from torch.utils.data import DataLoader # 데이터로더

# %%
x_train  =  torch.FloatTensor([[73,  80,  75], 
                               [93,  88,  93], 
                               [89,  91,  90], 
                               [96,  98,  100],   
                               [73,  66,  70]])  
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
dataset = TensorDataset(x_train, y_train)

# %% [markdown]
# ## DataLoader
# - DataLoader는 기본적으로 2개의 인자를 받음
#     - Dataset
#     - 미니 배치 크기 (일반적으로 2의 배수를 사용)
#     - shuffle=True로 설정하면 Epoch 마다 dataset을 섞어서 학습이 진행됨

# %%
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
    for batch_idx, samples in enumerate(dataloader):
        print(batch_idx)
        print(samples)
        x_train, y_train = samples
        
        # H(x) 계산
        prediction = model(x_train)

        # cost 계산
        cost = F.mse_loss(prediction, y_train)

        # cost로 H(x) 계산
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()

        print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
            epoch, nb_epochs, batch_idx+1, len(dataloader),
            cost.item()
            ))
# Out:
# 0
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch    0/20 Batch 1/3 Cost: 0.574093
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch    0/20 Batch 2/3 Cost: 0.940548
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    0/20 Batch 3/3 Cost: 0.515045
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch    1/20 Batch 1/3 Cost: 0.988496
# 1
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch    1/20 Batch 2/3 Cost: 0.599944
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    1/20 Batch 3/3 Cost: 0.109880
# 0
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch    2/20 Batch 1/3 Cost: 1.200399
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    2/20 Batch 2/3 Cost: 0.321937
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    2/20 Batch 3/3 Cost: 0.122483
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch    3/20 Batch 1/3 Cost: 0.561907
# 1
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch    3/20 Batch 2/3 Cost: 0.136817
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    3/20 Batch 3/3 Cost: 2.124007
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch    4/20 Batch 1/3 Cost: 0.860924
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch    4/20 Batch 2/3 Cost: 0.550028
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    4/20 Batch 3/3 Cost: 0.798713
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch    5/20 Batch 1/3 Cost: 0.213863
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch    5/20 Batch 2/3 Cost: 1.254747
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    5/20 Batch 3/3 Cost: 0.270627
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    6/20 Batch 1/3 Cost: 0.374660
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch    6/20 Batch 2/3 Cost: 0.667627
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch    6/20 Batch 3/3 Cost: 1.757923
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch    7/20 Batch 1/3 Cost: 0.563702
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch    7/20 Batch 2/3 Cost: 1.017483
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    7/20 Batch 3/3 Cost: 0.403179
# 0
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch    8/20 Batch 1/3 Cost: 0.571496
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch    8/20 Batch 2/3 Cost: 0.883868
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    8/20 Batch 3/3 Cost: 0.226501
# 0
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch    9/20 Batch 1/3 Cost: 1.143999
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch    9/20 Batch 2/3 Cost: 0.179661
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    9/20 Batch 3/3 Cost: 0.466466
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   10/20 Batch 1/3 Cost: 0.355110
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   10/20 Batch 2/3 Cost: 0.382158
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   10/20 Batch 3/3 Cost: 2.241265
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   11/20 Batch 1/3 Cost: 0.826350
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch   11/20 Batch 2/3 Cost: 1.061502
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   11/20 Batch 3/3 Cost: 0.127456
# 0
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch   12/20 Batch 1/3 Cost: 0.731180
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   12/20 Batch 2/3 Cost: 0.590690
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   12/20 Batch 3/3 Cost: 0.739916
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   13/20 Batch 1/3 Cost: 0.430951
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   13/20 Batch 2/3 Cost: 1.396075
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   13/20 Batch 3/3 Cost: 0.736560
# 0
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   14/20 Batch 1/3 Cost: 0.551544
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   14/20 Batch 2/3 Cost: 1.149047
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   14/20 Batch 3/3 Cost: 0.207596
# 0
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   15/20 Batch 1/3 Cost: 0.373487
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   15/20 Batch 2/3 Cost: 0.992236
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   15/20 Batch 3/3 Cost: 1.053680
# 0
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   16/20 Batch 1/3 Cost: 1.029939
# 1
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch   16/20 Batch 2/3 Cost: 0.330216
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   16/20 Batch 3/3 Cost: 0.959136
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   17/20 Batch 1/3 Cost: 0.405523
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   17/20 Batch 2/3 Cost: 0.325406
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   17/20 Batch 3/3 Cost: 2.371062
# 0
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   18/20 Batch 1/3 Cost: 0.798130
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch   18/20 Batch 2/3 Cost: 0.695982
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   18/20 Batch 3/3 Cost: 1.650058
# 0
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   19/20 Batch 1/3 Cost: 0.840204
# 1
# [tensor([[93., 88., 93.],
#         [73., 80., 75.]]), tensor([[185.],
#         [152.]])]
# Epoch   19/20 Batch 2/3 Cost: 0.741499
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   19/20 Batch 3/3 Cost: 0.918422
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   20/20 Batch 1/3 Cost: 0.230409
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   20/20 Batch 2/3 Cost: 1.363851
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   20/20 Batch 3/3 Cost: 0.344414

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]]) 
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[151.2357]], grad_fn=<AddmmBackward0>)
